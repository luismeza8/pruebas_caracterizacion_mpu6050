# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
celular = pd.read_csv('/home/lm/Code/Horus/Pruebas/mpu_silla/celular.csv')
mpu = pd.read_csv('/home/lm/Code/Horus/Pruebas/mpu_silla/mpu.csv')

# %%
x = mpu.Medicion

plt.plot(x, celular.gFx, label='celular')
plt.plot(x, mpu.Aceleracion_X, label='mpu')
plt.legend()

plt.show()

# %%
x = mpu.Medicion

plt.plot(x, celular.gFy, label='celular')
plt.plot(x, mpu.Aceleracion_Y, label='mpu')
plt.legend()

plt.show()

# %%
x = mpu.Medicion

plt.plot(x, celular.gFz, label='celular')
plt.plot(x, mpu.Aceleracion_Z, label='mpu')
plt.legend()

plt.show()
